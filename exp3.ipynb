# %%
import cv2
import matplotlib.pyplot as plt
gray_image = cv2.imread("/home/sam/Desktop/dipt/Histogram-of-an-images/images/bw.jpg")
gray_image = cv2.resize(gray_image, (427, 284))
color_image = cv2.imread("/home/sam/Desktop/dipt/Histogram-of-an-images/images/color.jpg")
color_image = cv2.resize(color_image, (489, 367))
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Color Image",color_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt 
gray_image = cv2.imread("/home/sam/Desktop/dipt/Histogram-of-an-images/images/bw.jpg")
gray_image = cv2.resize(gray_image, (427, 284))
color_image = cv2.imread("/home/sam/Desktop/dipt/Histogram-of-an-images/images/color.jpg")
color_image = cv2.resize(color_image, (489, 367))
hist=cv2.calcHist(gray_image,[0],None,[255],[0,255])
hist1=cv2.calcHist(color_image,[0],None,[255],[0,255])
plt.figure()
plt.title("Histogram")
plt.xlabel("")
plt.ylabel("pixel count")
plt.stem()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 13
#      11 plt.xlabel("")
#      12 plt.ylabel("pixel count")
# ---> 13 plt.stem()
#      14 plt.show()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:3817, in stem(linefmt, markerfmt, basefmt, bottom, label, orientation, data, *args)
#    3806 @_copy_docstring_and_deprecators(Axes.stem)
#    3807 def stem(
#    3808     *args: ArrayLike | str,
#    (...)
#    3815     data=None,
#    3816 ) -> StemContainer:
# -> 3817     return gca().stem(
#    3818         *args,
#    3819         linefmt=linefmt,
#    3820         markerfmt=markerfmt,
#    3821         basefmt=basefmt,
#    3822         bottom=bottom,
#    3823         label=label,
#    3824         orientation=orientation,
#    3825         **({"data": data} if data is not None else {}),
#    3826     )
#
# ...
